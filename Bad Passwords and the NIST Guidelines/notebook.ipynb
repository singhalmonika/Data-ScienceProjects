# %% [markdown]
# ## # Introduction
# <p><img src="https://i.imgur.com/kjWF1So.jpg" alt="Different characters on a computer screen"></p>
# <p>According to a 2019 <a href="https://storage.googleapis.com/gweb-uniblog-publish-prod/documents/PasswordCheckup-HarrisPoll-InfographicFINAL.pdf">Google / Harris Poll</a>, 24% of Americans have used common passwords, like <code>abc123</code>, <code>Password</code>, and <code>Admin</code>. Even more concerning, 59% of Americans have incorporated personal information, such as their name or birthday, into their password. This makes it unsurprising that 4 in 10 Americans have had their personal information compromised online. Passwords with commonly used phrases and personal information makes cracking a password drastically easier.</p>
# <p>You may have noticed over the years that password requirements have increased in complexity, including recommendations to change your passwords every couple of months. Compiled from industry recommendations, below is a list of passwords requirements you will be asked to test: </p>
# <p><strong>Password Requirments:</strong></p>
# <ol>
# <li>Must be at least 10 characters in length</li>
# <li>Must contain at least:<ul>
# <li>one lower case letter </li>
# <li>one upper case letter </li>
# <li>one numeric character </li>
# <li>one non-alphanumeric character</li></ul></li>
# <li>Must not contain the phrase <code>password</code> (case insensitive)</li>
# <li>Must not contain the user's first or last name, e.g., if the user's name is <code>John Smith</code>, then <code>SmItH876!</code> is not a valid password.</li>
# </ol>
# <p>Here is the dataset that you will investigate this project:</p>
# <div style="background-color: #ebf4f7; color: #595959; text-align:left; vertical-align: middle; padding: 15px 25px 15px 25px; line-height: 1.6;">
#     <div style="font-size:20px"><b>datasets/logins.csv</b></div>
# Each row represents a login credential. There are no missing values and you can consider the dataset "clean".
# <ul>
#     <li><b>id:</b> the user's unique ID.</li>
#     <li><b>username:</b> the username with the format {firstname}.{lastname}.</li>
#     <li><b>password:</b> the password that may or may not meet the requirements. <i>Note, passwords should never be saved in plaintext, always encrypt them when working with real live passwords!</i></li>
# </ul>
# </div>
# <p>Warning: This dataset contains some <strong>real</strong> passwords leaked from <strong>real</strong> websites. These passwords have been filtered, but may still include words that are explicit and offensive.</p>
# <p>From here on out, it will be your task to explore and manipulate the existing data until you can answer the two questions described in the instructions panel. Feel free to import as many packages as you need to complete your task, and add cells as necessary. Finally, remember that you are only tested on your answer, not on the methods you use to arrive at the answer!</p>
# <p><strong>Note:</strong> To complete this project, you need to know how to manipulate strings in pandas DataFrames and be familiar with regular expressions. Before starting this project we recommend that you have completed the following courses: <a href="https://learn.datacamp.com/courses/data-cleaning-in-python">Data Cleaning in Python</a> and <a href="https://learn.datacamp.com/courses/regular-expressions-in-python">Regular Expressions in Python</a>.</p>

# %%
# Use this cell to begin your analysis, and add as many as you would like!
import pandas as pd
login_dataset = pd.read_csv("datasets/logins.csv")
login_dataset.head(25)
# Out:
#     id            username                    password
# 0    1      vance.jennings              vanceRules888!
# 1    2      consuelo.eaton       Mail_Pen%Scarlets.414
# 2    3     mitchel.perkins                    Z00+1960
# 3    4      odessa.vaughan                   D-rockyou
# 4    5      araceli.wilder                  Araceli}r3
# 5    6    shawn.harrington                 126_239_123
# 6    7          evelyn.gay                `4:&iAt$'o~(
# 7    8         noreen.hale                 25941829163
# 8    9         gladys.ward                 =Wj1`i)xYYZ
# 9   10     brant.zimmerman                   L?4)OSB$r
# 10  11       leanna.abbott                @_2.#,%~>~&+
# 11  12     milford.hubbard                Milford<3Tom
# 12  13           mamie.fox                  chichi821?
# 13  14       jamie.cochran  Deviants.Assists.Impede+24
# 14  15  nathaniel.robinson                  1204380071
# 15  16          lorrie.gay                Q0G:[@u9*_`_
# 16  17        domingo.dyer                     VeOw{*p
# 17  18      martin.pacheco                   MP1985???
# 18  19       shelby.massey                      787175
# 19  20     rosella.barrett                     TOBBY05
# 20  21       karina.morton                iDYuPurXYpW6
# 21  22     leticia.sanford  Parole:Seagull+Cession-148
# 22  23       jenny.woodard                 9^+}+7.*0}1
# 23  24     brandie.webster   321.Snuffs-Pinball.Nougat
# 24  25      sabrina.suarez                 CZg&Gl`Jfh]

# %%
# check for null values
print(login_dataset.shape)
login_dataset.info()
# Out:
# (982, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 3 columns):
# id          982 non-null int64
# username    982 non-null object
# password    982 non-null object
# dtypes: int64(1), object(2)
# memory usage: 23.1+ KB

# %%
len_check=login_dataset['password'].str.len() >=10
len_check
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9      False
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25     False
# 26     False
# 27     False
# 28      True
# 29      True
#        ...
# 952     True
# 953    False
# 954     True
# 955    False
# 956    False
# 957     True
# 958     True
# 959     True
# 960    False
# 961     True
# 962     True
# 963     True
# 964     True
# 965    False
# 966     True
# 967     True
# 968    False
# 969     True
# 970     True
# 971     True
# 972     True
# 973     True
# 974    False
# 975     True
# 976     True
# 977    False
# 978     True
# 979     True
# 980    False
# 981     True
# Name: password, Length: 982, dtype: bool

# %%
import re
re.findall(r"[A-Z]+","Milford<3Tompassword")
# Out:
# ['M', 'T']

# %%
re.findall(r"[a-z]+","Milford<3Tompassword")
# Out:
# ['ilford', 'ompassword']

# %%
phrase_check =login_dataset['password'].str.contains("password",case=False)
phrase_check
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# 979    False
# 980    False
# 981    False
# Name: password, Length: 982, dtype: bool

# %%
capital_check=login_dataset['password'].str.contains("[A-Z]+")
capital_check
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
# 6       True
# 7      False
# 8       True
# 9       True
# 10     False
# 11      True
# 12     False
# 13      True
# 14     False
# 15      True
# 16      True
# 17      True
# 18     False
# 19      True
# 20      True
# 21      True
# 22     False
# 23      True
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 952    False
# 953     True
# 954     True
# 955     True
# 956     True
# 957     True
# 958     True
# 959     True
# 960     True
# 961     True
# 962     True
# 963    False
# 964     True
# 965     True
# 966     True
# 967     True
# 968    False
# 969    False
# 970     True
# 971     True
# 972     True
# 973     True
# 974     True
# 975     True
# 976    False
# 977    False
# 978     True
# 979     True
# 980    False
# 981     True
# Name: password, Length: 982, dtype: bool

# %%
lowercheck=login_dataset['password'].str.contains("[a-z]+")
lowercheck
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
# 5      False
# 6       True
# 7      False
# 8       True
# 9       True
# 10     False
# 11      True
# 12      True
# 13      True
# 14     False
# 15      True
# 16      True
# 17     False
# 18     False
# 19     False
# 20      True
# 21      True
# 22     False
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 952    False
# 953     True
# 954     True
# 955     True
# 956     True
# 957     True
# 958     True
# 959     True
# 960     True
# 961     True
# 962     True
# 963     True
# 964     True
# 965     True
# 966     True
# 967     True
# 968     True
# 969     True
# 970     True
# 971     True
# 972     True
# 973     True
# 974     True
# 975     True
# 976     True
# 977     True
# 978     True
# 979     True
# 980     True
# 981     True
# Name: password, Length: 982, dtype: bool

# %%
number_check=login_dataset['password'].str.contains("[0-9]+")
number_check
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16     False
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24     False
# 25      True
# 26      True
# 27     False
# 28     False
# 29      True
#        ...
# 952     True
# 953    False
# 954     True
# 955     True
# 956    False
# 957     True
# 958     True
# 959     True
# 960     True
# 961     True
# 962     True
# 963    False
# 964     True
# 965    False
# 966     True
# 967     True
# 968     True
# 969     True
# 970     True
# 971     True
# 972     True
# 973     True
# 974    False
# 975     True
# 976     True
# 977     True
# 978     True
# 979     True
# 980    False
# 981     True
# Name: password, Length: 982, dtype: bool

# %%
non_alpha_check= login_dataset['password'].str.contains("\W+")
non_alpha_check
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
# 6       True
# 7      False
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14     False
# 15      True
# 16      True
# 17      True
# 18     False
# 19     False
# 20     False
# 21      True
# 22      True
# 23      True
# 24      True
# 25     False
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 952    False
# 953     True
# 954    False
# 955     True
# 956     True
# 957    False
# 958     True
# 959     True
# 960     True
# 961     True
# 962    False
# 963    False
# 964     True
# 965     True
# 966     True
# 967    False
# 968    False
# 969     True
# 970     True
# 971     True
# 972     True
# 973    False
# 974     True
# 975    False
# 976     True
# 977    False
# 978     True
# 979    False
# 980     True
# 981    False
# Name: password, Length: 982, dtype: bool

# %%
username_dataset=login_dataset["username"].str.split("\.",expand=True)
username_dataset
login_dataset["first_name"]=username_dataset.iloc[:,0]
login_dataset["last_name"]=username_dataset.iloc[:,1]

# %%
index_login=login_dataset['password'].index
login_dataset.iloc[index_login]
# Out:
#       id            username                      password first_name  \
# 0      1      vance.jennings                vanceRules888!      vance
# 1      2      consuelo.eaton         Mail_Pen%Scarlets.414   consuelo
# 2      3     mitchel.perkins                      Z00+1960    mitchel
# 3      4      odessa.vaughan                     D-rockyou     odessa
# 4      5      araceli.wilder                    Araceli}r3    araceli
# 5      6    shawn.harrington                   126_239_123      shawn
# 6      7          evelyn.gay                  `4:&iAt$'o~(     evelyn
# 7      8         noreen.hale                   25941829163     noreen
# 8      9         gladys.ward                   =Wj1`i)xYYZ     gladys
# 9     10     brant.zimmerman                     L?4)OSB$r      brant
# 10    11       leanna.abbott                  @_2.#,%~>~&+     leanna
# 11    12     milford.hubbard                  Milford<3Tom    milford
# 12    13           mamie.fox                    chichi821?      mamie
# 13    14       jamie.cochran    Deviants.Assists.Impede+24      jamie
# 14    15  nathaniel.robinson                    1204380071  nathaniel
# 15    16          lorrie.gay                  Q0G:[@u9*_`_     lorrie
# 16    17        domingo.dyer                       VeOw{*p    domingo
# 17    18      martin.pacheco                     MP1985???     martin
# 18    19       shelby.massey                        787175     shelby
# 19    20     rosella.barrett                       TOBBY05    rosella
# 20    21       karina.morton                  iDYuPurXYpW6     karina
# 21    22     leticia.sanford    Parole:Seagull+Cession-148    leticia
# 22    23       jenny.woodard                   9^+}+7.*0}1      jenny
# 23    24     brandie.webster     321.Snuffs-Pinball.Nougat    brandie
# 24    25      sabrina.suarez                   CZg&Gl`Jfh]    sabrina
# 25    26        dianna.munoz                     munoZ_001     dianna
# 26    27        julia.savage                     z5dm_c"R\      julia
# 27    28        loretta.bass                       %%%bass    loretta
# 28    29     joaquin.walters                    ..LqgIKww.    joaquin
# 29    30          rene.small                    ]9"mP(kM4c       rene
# ..   ...                 ...                           ...        ...
# 952  953    christa.morrison                    3322368243    christa
# 953  954      clarence.britt                     zK*'%.ko_   clarence
# 954  955     carmela.clayton               bZ3ME2PRIfnjXtQ    carmela
# 955  956         royce.combs                      fs8=[z|Z      royce
# 956  957        devon.holman                       \fQI=.w      devon
# 957  958       becky.hickman                3su9hb6KiZxCqo      becky
# 958  959        deena.holmes  Sibilant:Gyrates%Rescans%566      deena
# 959  960       mark.chandler    Jackal-Decree*467-Shivered       mark
# 960  961       carmelo.byers                       #x`iYc0    carmelo
# 961  962  mohammed.carpenter     Firing;921.Tubules-Prided   mohammed
# 962  963      rico.valentine              14Gfa5XyjzBYUpJ8       rico
# 963  964     angel.jefferson                    volunteers      angel
# 964  965      chrystal.burns                   ChRYSTAL90?   chrystal
# 965  966        irma.vasquez                      JjQqr.<;       irma
# 966  967         taylor.kent                  >L0/d"8=omzy     taylor
# 967  968       deloris.dixon                    4gAyvvcOeA    deloris
# 968  969        julian.gross                        jv0805     julian
# 969  970          joey.poole                   37z<wi+o/vb       joey
# 970  971        noel.montoya     Riskier:Spikes_Grasped=27       noel
# 971  972       josef.hoffman   Unhidden-Flatus*753-Figurer      josef
# 972  973       jorge.patrick                   Freedom_85!      jorge
# 973  974       rogelio.payne                  pKfOP4DYATEj    rogelio
# 974  975       lucille.stark                     y>!YHfgH$    lucille
# 975  976        freeman.rose                  cHw2Leth5JXY    freeman
# 976  977       monica.flores                   *;~a8dq5%s'     monica
# 977  978       autumn.alford                      pink3602     autumn
# 978  979       miriam.haynes      Gizzard.Muse+Patters_857     miriam
# 979  980        genaro.russo                 Rm3OwUfobjYxq     genaro
# 980  981          lora.quinn                       bn#_k:}       lora
# 981  982     elmer.mccormick                  IzXEo2ghZBJm      elmer
#
#       last_name
# 0      jennings
# 1         eaton
# 2       perkins
# 3       vaughan
# 4        wilder
# 5    harrington
# 6           gay
# 7          hale
# 8          ward
# 9     zimmerman
# 10       abbott
# 11      hubbard
# 12          fox
# 13      cochran
# 14     robinson
# 15          gay
# 16         dyer
# 17      pacheco
# 18       massey
# 19      barrett
# 20       morton
# 21      sanford
# 22      woodard
# 23      webster
# 24       suarez
# 25        munoz
# 26       savage
# 27         bass
# 28      walters
# 29        small
# ..          ...
# 952    morrison
# 953       britt
# 954     clayton
# 955       combs
# 956      holman
# 957     hickman
# 958      holmes
# 959    chandler
# 960       byers
# 961   carpenter
# 962   valentine
# 963   jefferson
# 964       burns
# 965     vasquez
# 966        kent
# 967       dixon
# 968       gross
# 969       poole
# 970     montoya
# 971     hoffman
# 972     patrick
# 973       payne
# 974       stark
# 975        rose
# 976      flores
# 977      alford
# 978      haynes
# 979       russo
# 980       quinn
# 981   mccormick
#
# [982 rows x 5 columns]

# %%
first = "vance"

# %%
last = "jennings"

# %%
first_name_occur= re.findall(first,"VanceRules888!".lower())
bool(first_name_occur)
# Out:
# True

# %%
second_name_occur = re.findall(last,"VanceRules888!".lower())
bool(second_name_occur) | bool(first_name_occur)
# Out:
# True

# %%
userPassLi =[]

# %%
def check_userexistInPass():
   for i in login_dataset.index:
     first_name_occur = re.findall(login_dataset.iloc[i,3],login_dataset.iloc[i,2].lower())
     last_name_occur = re.findall(login_dataset.iloc[i,4],login_dataset.iloc[i,2].lower())
     userPassLi.append(bool(first_name_occur)|bool(last_name_occur))

# %%
check_userexistInPass()
login_dataset["check_user_pass"] = userPassLi

# %%
print(login_dataset.head())
# Out:
#    id         username               password first_name last_name  \
# 0   1   vance.jennings         vanceRules888!      vance  jennings
# 1   2   consuelo.eaton  Mail_Pen%Scarlets.414   consuelo     eaton
# 2   3  mitchel.perkins               Z00+1960    mitchel   perkins
# 3   4   odessa.vaughan              D-rockyou     odessa   vaughan
# 4   5   araceli.wilder             Araceli}r3    araceli    wilder
#
#    check_user_pass
# 0             True
# 1            False
# 2            False
# 3            False
# 4             True

# %%
total_users = len(login_dataset)
total_users
# Out:
# 982

# %%
valid_password = login_dataset[len_check & capital_check & lowercheck & number_check & non_alpha_check & (login_dataset["check_user_pass"] == False) & (phrase_check != True)]
valid_password
# Out:
#       id             username                        password first_name  \
# 1      2       consuelo.eaton           Mail_Pen%Scarlets.414   consuelo
# 6      7           evelyn.gay                    `4:&iAt$'o~(     evelyn
# 8      9          gladys.ward                     =Wj1`i)xYYZ     gladys
# 13    14        jamie.cochran      Deviants.Assists.Impede+24      jamie
# 15    16           lorrie.gay                    Q0G:[@u9*_`_     lorrie
# 21    22      leticia.sanford      Parole:Seagull+Cession-148    leticia
# 23    24      brandie.webster       321.Snuffs-Pinball.Nougat    brandie
# 29    30           rene.small                      ]9"mP(kM4c       rene
# 30    31         rosanna.reid    Outguess%Dresser:Derails=669    rosanna
# 33    34        patrica.hicks   Wanderer.849+Enlarges:Olympia    patrica
# 36    37      adriana.daniels                    hmKP1w4h'V.Y    adriana
# 39    40           clay.brady                      Zz%'XFaZZ3       clay
# 41    42           ariel.chen         Violas-Insect*Agony:726      ariel
# 43    44       vito.nicholson    75%Capsules=Volatile*Fluency       vito
# 46    47        bradford.rios         89:Admirer-Bands*Felons   bradford
# 48    49         junior.burch      Banality;520=Resale-Helper     junior
# 59    60     landon.middleton     Dampest*Airports+Senora=485     landon
# 62    63     dominique.dawson      185_Newlook-Depraves+Cameo  dominique
# 67    68       keisha.morales      Outlast:238_Peachy*Waviest     keisha
# 74    75             bud.knox  384;Retailed%Freshens*Interred        bud
# 81    82         seymour.ball                    \b.N[7tRK9HQ    seymour
# 87    88        emilia.hurley          Sons=Exam-Innovate-546     emilia
# 89    90        jordan.hurley                      kokjooN91!     jordan
# 90    91          sheryl.ross                    ~e%;Ear(&jo8     sheryl
# 99   100        jeanne.battle    320%Snatches*Combat-Mortices     jeanne
# 106  107          vera.macias                    ;-elY*W-6i>]       vera
# 114  115         marshall.day           Fee+Reworks-Refit-837   marshall
# 116  117       natalia.macias     Rustics.545-Relicts:Rimless    natalia
# 121  122      raphael.blevins     Clobber_Framed:Captions-214    raphael
# 124  125        lolita.murphy                    :f~v2aFPd*P'     lolita
# ..   ...                  ...                             ...        ...
# 870  871         berta.holman                     l5(~-T,0E;F      berta
# 871  872        chance.lawson     971:Dictum_Boniest+Serenata     chance
# 891  892       marisa.preston                     y'+LG5Ofa&A     marisa
# 892  893    mario.blankenship  Document.Tottered%337:Treaties      mario
# 895  896           letha.kemp                     h_AUv3<jy@-      letha
# 899  900             ida.wood      Unlocks.998_Unstuck%Voters        ida
# 902  903           diego.rice                      o2pXIF\\1\      diego
# 907  908  alexandra.contreras       Await:Fancies;Needled+685  alexandra
# 908  909         bridget.rowe       Lobsters.802%Bar-Symbolic    bridget
# 913  914       benita.anthony        Famed*Biasing;Adepts=309     benita
# 918  919       trevor.perkins                      7pn:*WWYao     trevor
# 922  923          arthur.buck      Derates+Forges_198.Discant     arthur
# 927  928       roberto.torres   Definite+516_Balding*Wretches    roberto
# 930  931           davis.roth       Retried+977+Blunted%Strop      davis
# 933  934    josephine.morales                     k5TIB45{vDB  josephine
# 934  935            evan.chan  Objector+Toboggan=244+Fuelling       evan
# 935  936      leanna.richards       559:Entree*Whippet=Slater     leanna
# 937  938        mohammad.ware         Naomi;612*Scouring=Dish   mohammad
# 940  941            zane.bond                      1Ga*)#Tg*<       zane
# 948  949         annie.mendez                     O_]<CL"1zZ,      annie
# 950  951       rebekah.sharpe     414*Validly:Swoops%Delusive    rebekah
# 951  952   zachariah.shepherd    981*Crowning*Gravies;Aquifer  zachariah
# 958  959         deena.holmes    Sibilant:Gyrates%Rescans%566      deena
# 959  960        mark.chandler      Jackal-Decree*467-Shivered       mark
# 961  962   mohammed.carpenter       Firing;921.Tubules-Prided   mohammed
# 966  967          taylor.kent                    >L0/d"8=omzy     taylor
# 970  971         noel.montoya       Riskier:Spikes_Grasped=27       noel
# 971  972        josef.hoffman     Unhidden-Flatus*753-Figurer      josef
# 972  973        jorge.patrick                     Freedom_85!      jorge
# 978  979        miriam.haynes        Gizzard.Muse+Patters_857     miriam
#
#        last_name  check_user_pass
# 1          eaton            False
# 6            gay            False
# 8           ward            False
# 13       cochran            False
# 15           gay            False
# 21       sanford            False
# 23       webster            False
# 29         small            False
# 30          reid            False
# 33         hicks            False
# 36       daniels            False
# 39         brady            False
# 41          chen            False
# 43     nicholson            False
# 46          rios            False
# 48         burch            False
# 59     middleton            False
# 62        dawson            False
# 67       morales            False
# 74          knox            False
# 81          ball            False
# 87        hurley            False
# 89        hurley            False
# 90          ross            False
# 99        battle            False
# 106       macias            False
# 114          day            False
# 116       macias            False
# 121      blevins            False
# 124       murphy            False
# ..           ...              ...
# 870       holman            False
# 871       lawson            False
# 891      preston            False
# 892  blankenship            False
# 895         kemp            False
# 899         wood            False
# 902         rice            False
# 907    contreras            False
# 908         rowe            False
# 913      anthony            False
# 918      perkins            False
# 922         buck            False
# 927       torres            False
# 930         roth            False
# 933      morales            False
# 934         chan            False
# 935     richards            False
# 937         ware            False
# 940         bond            False
# 948       mendez            False
# 950       sharpe            False
# 951     shepherd            False
# 958       holmes            False
# 959     chandler            False
# 961    carpenter            False
# 966         kent            False
# 970      montoya            False
# 971      hoffman            False
# 972      patrick            False
# 978       haynes            False
#
# [246 rows x 6 columns]

# %%
valid_pass_length = len(valid_password)
valid_pass_length
# Out:
# 246

# %%
invalid_perc =(total_users - valid_pass_length)/total_users
bad_pass = round(invalid_perc,2)
bad_pass
# Out:
# 0.75

# %%
invalid_users = login_dataset[~len_check | ~capital_check | ~lowercheck | ~number_check | ~non_alpha_check|(login_dataset["check_user_pass"] == True) | phrase_check]
invalid_users
# Out:
#       id            username          password first_name   last_name  \
# 0      1      vance.jennings    vanceRules888!      vance    jennings
# 2      3     mitchel.perkins          Z00+1960    mitchel     perkins
# 3      4      odessa.vaughan         D-rockyou     odessa     vaughan
# 4      5      araceli.wilder        Araceli}r3    araceli      wilder
# 5      6    shawn.harrington       126_239_123      shawn  harrington
# 7      8         noreen.hale       25941829163     noreen        hale
# 9     10     brant.zimmerman         L?4)OSB$r      brant   zimmerman
# 10    11       leanna.abbott      @_2.#,%~>~&+     leanna      abbott
# 11    12     milford.hubbard      Milford<3Tom    milford     hubbard
# 12    13           mamie.fox        chichi821?      mamie         fox
# 14    15  nathaniel.robinson        1204380071  nathaniel    robinson
# 16    17        domingo.dyer           VeOw{*p    domingo        dyer
# 17    18      martin.pacheco         MP1985???     martin     pacheco
# 18    19       shelby.massey            787175     shelby      massey
# 19    20     rosella.barrett           TOBBY05    rosella     barrett
# 20    21       karina.morton      iDYuPurXYpW6     karina      morton
# 22    23       jenny.woodard       9^+}+7.*0}1      jenny     woodard
# 24    25      sabrina.suarez       CZg&Gl`Jfh]    sabrina      suarez
# 25    26        dianna.munoz         munoZ_001     dianna       munoz
# 26    27        julia.savage         z5dm_c"R\      julia      savage
# 27    28        loretta.bass           %%%bass    loretta        bass
# 28    29     joaquin.walters        ..LqgIKww.    joaquin     walters
# 31    32       taylor.kramer            jtc123     taylor      kramer
# 32    33     jacquelyn.brady   O0CY5v9sVjfEBHq  jacquelyn       brady
# 34    35        roger.golden           xq-SaL]      roger      golden
# 35    36       dannie.gaines            badboy     dannie      gaines
# 37    38          ervin.dyer         E5IqavZ5a      ervin        dyer
# 38    39         gus.padilla  CIRUJANODENTISTA        gus     padilla
# 40    41     salvador.osborn        ]Yj=%K*M*F   salvador      osborn
# 42    43       jarrett.marsh         C4DUfY5pX    jarrett       marsh
# ..   ...                 ...               ...        ...         ...
# 941  942      mitch.ferguson          4\,Y4cCg      mitch    ferguson
# 942  943       donna.mcmahon         Ih6ymtaQh      donna     mcmahon
# 943  944          andrea.day          akera007     andrea         day
# 944  945        stella.hicks        wCmsoVU1EF     stella       hicks
# 945  946  willard.williamson       _)/(\7$.!.*    willard  williamson
# 946  947      tanisha.ortega        Mb8v0u1WDL    tanisha      ortega
# 947  948          amber.vega           *O|L~2*      amber        vega
# 949  950       neil.phillips       _lHNM/cf%P$       neil    phillips
# 952  953    christa.morrison        3322368243    christa    morrison
# 953  954      clarence.britt         zK*'%.ko_   clarence       britt
# 954  955     carmela.clayton   bZ3ME2PRIfnjXtQ    carmela     clayton
# 955  956         royce.combs          fs8=[z|Z      royce       combs
# 956  957        devon.holman           \fQI=.w      devon      holman
# 957  958       becky.hickman    3su9hb6KiZxCqo      becky     hickman
# 960  961       carmelo.byers           #x`iYc0    carmelo       byers
# 962  963      rico.valentine  14Gfa5XyjzBYUpJ8       rico   valentine
# 963  964     angel.jefferson        volunteers      angel   jefferson
# 964  965      chrystal.burns       ChRYSTAL90?   chrystal       burns
# 965  966        irma.vasquez          JjQqr.<;       irma     vasquez
# 967  968       deloris.dixon        4gAyvvcOeA    deloris       dixon
# 968  969        julian.gross            jv0805     julian       gross
# 969  970          joey.poole       37z<wi+o/vb       joey       poole
# 973  974       rogelio.payne      pKfOP4DYATEj    rogelio       payne
# 974  975       lucille.stark         y>!YHfgH$    lucille       stark
# 975  976        freeman.rose      cHw2Leth5JXY    freeman        rose
# 976  977       monica.flores       *;~a8dq5%s'     monica      flores
# 977  978       autumn.alford          pink3602     autumn      alford
# 979  980        genaro.russo     Rm3OwUfobjYxq     genaro       russo
# 980  981          lora.quinn           bn#_k:}       lora       quinn
# 981  982     elmer.mccormick      IzXEo2ghZBJm      elmer   mccormick
#
#      check_user_pass
# 0               True
# 2              False
# 3              False
# 4               True
# 5              False
# 7              False
# 9              False
# 10             False
# 11              True
# 12             False
# 14             False
# 16             False
# 17             False
# 18             False
# 19             False
# 20             False
# 22             False
# 24             False
# 25              True
# 26             False
# 27              True
# 28             False
# 31             False
# 32             False
# 34             False
# 35             False
# 37             False
# 38             False
# 40             False
# 42             False
# ..               ...
# 941            False
# 942            False
# 943            False
# 944            False
# 945            False
# 946            False
# 947            False
# 949            False
# 952            False
# 953            False
# 954            False
# 955            False
# 956            False
# 957            False
# 960            False
# 962            False
# 963            False
# 964             True
# 965            False
# 967            False
# 968            False
# 969            False
# 973            False
# 974            False
# 975            False
# 976            False
# 977            False
# 979            False
# 980            False
# 981            False
#
# [736 rows x 6 columns]

# %%
email_list = invalid_users["username"].sort_values()
email_list
# Out:
# 931           abdul.rowland
# 713            addie.cherry
# 857            adele.moreno
# 291            adeline.bush
# 663             adolfo.kane
# 775             adolfo.lara
# 51             ahmad.hopper
# 298              aida.combs
# 898           aisha.jenkins
# 471               al.dunlap
# 356            alana.franco
# 546         alberta.leblanc
# 306            alec.robbins
# 831    alejandra.stephenson
# 44          alejandro.burke
# 195        alejandro.nieves
# 483        alexander.thomas
# 920       alexandria.hinton
# 93        alexis.mccullough
# 219         alexis.reynolds
# 456          alfonso.weaver
# 366           alfonzo.johns
# 595          alisa.campbell
# 781             alisa.cohen
# 442             alison.neal
# 452          allan.marshall
# 338           alonzo.fowler
# 751           amado.bridges
# 207        amado.fitzgerald
# 543           amber.summers
#                ...
# 64              ursula.wood
# 664       valentin.castillo
# 551           valeria.curry
# 0            vance.jennings
# 731           vanessa.davis
# 516             verna.white
# 246          vicente.hopper
# 904            victor.bryan
# 626              vilma.hart
# 280       vincent.contreras
# 349            viola.foster
# 414             violet.horn
# 906           virgie.atkins
# 660        walter.blackwell
# 880           walter.conner
# 264           walter.hughes
# 118        wilburn.shepherd
# 633         wilford.kaufman
# 326         wilfredo.keller
# 945      willard.williamson
# 286      williams.mcfarland
# 872           williams.rios
# 594        willis.cervantes
# 465            wyatt.finley
# 409             young.booth
# 860        yvette.whitfield
# 545            yvonne.munoz
# 634            zachary.huff
# 417            zelma.abbott
# 130           zelma.rosario
# Name: username, Length: 736, dtype: object
